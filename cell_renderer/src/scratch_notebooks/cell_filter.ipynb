# %%
import scanpy as sc
import pandas as pd

# %%
adata = sc.read_h5ad('ss2_pancreas_aging.h5ad')

# %%
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata)
# Out:
# /home/shawn/miniconda3/envs/msse-python/lib/python3.11/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
single_cell = adata[167, adata.var[adata.var['highly_variable']].index]

# %%
single_cell.obs
# Out:
#                           donor_age inferred_cell_type  \
# cellID
# GSM2172559_1000101205.B1         38               beta
#
#                          development_stage_ontology_term_id  \
# cellID
# GSM2172559_1000101205.B1                     HsapDv:0000132
#
#                          cell_type_ontology_term_id sex_ontology_term_id  \
# cellID
# GSM2172559_1000101205.B1                 CL:0000169         PATO:0000383
#
#                              donor_id  \
# cellID
# GSM2172559_1000101205.B1  DID_scRSq06
#
#                          self_reported_ethnicity_ontology_term_id  \
# cellID
# GSM2172559_1000101205.B1                           HANCESTRO:0005
#
#                          cause_of_death  body_mass_index  \
# cellID
# GSM2172559_1000101205.B1         Stroke             29.5
#
#                          organism_ontology_term_id  ... tissue_type  \
# cellID                                              ...
# ...

# %%
single_cell.write_h5ad("single_pancreatic_cell.h5ad")

# %%
if "highly_variable" in single_cell.obs:
    print(True)

# %%
single_cell.var
# Out:
#                  feature_is_filtered            feature_name  \
# ENSG00000166535                False                   A2ML1
# ENSG00000118017                False                   A4GNT
# ENSG00000250420                False  AACSP1_ENSG00000250420
# ENSG00000114771                False                   AADAC
# ENSG00000204518                False                 AADACL4
# ...                              ...                     ...
# ENSG00000132801                False                  ZSWIM3
# ENSG00000174442                False                  ZWILCH
# ENSG00000122952                False                   ZWINT
# ENSG00000198205                False                    ZXDA
# ENSG00000203995                False                  ZYG11A
#
#                 feature_reference feature_biotype feature_length  \
# ENSG00000166535    NCBITaxon:9606            gene            592
# ENSG00000118017    NCBITaxon:9606            gene           1779
# ...

# %%
attribute = sc.queries.biomart_annotations('hsapiens', ['ensembl_gene_id', 'phenotype_description', 'transcript_biotype', 'tmhmm'], use_cache=True)
attribute
# Out:
#         ensembl_gene_id                        phenotype_description  \
# 0       ENSG00000198888                Isolated complex I deficiency
# 1       ENSG00000198888            Leber hereditary optic neuropathy
# 2       ENSG00000198888                                        MELAS
# 3       ENSG00000198888  Mitochondrial DNA-associated Leigh syndrome
# 4       ENSG00000198888                          LEBER OPTIC ATROPHY
# ...                 ...                                          ...
# 172876  ENSG00000271741                                          NaN
# 172877  ENSG00000163867                      Intellectual disability
# 172878  ENSG00000163867                      Intellectual disability
# 172879  ENSG00000197056                                          NaN
# 172880  ENSG00000117632                                          NaN
#
#              transcript_biotype    tmhmm
# 0                protein_coding  TMhelix
# 1                protein_coding  TMhelix
# ...

# %%
attribute['phenotype_description'].unique()
# Out:
# array(['Gitelman-like kidney tubulopathy due to mitochondrial DNA mutation',
#        'MELAS', 'MERRF', ..., 'DPH5-related neurodevelopmental disorder',
#        'Ziegler-Huang syndrome', 'SLC30A7-associated Joubert syndrome'],
#       dtype=object)
